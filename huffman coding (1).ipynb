# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
#Using python's PIL module to process images 
#coding: utf-8
class node: #Node's class
         #Define node construction method
    def __init__(self,right=None,left=None, parent=None, weight=0, code=None):
        self.left = left 
        self.right = right 
        self.parent = parent 
        self.weight = weight #weight
        self.code = code #Node value
        
 #Define function, convert the color image to a gray image, at this time each pixel of the image can be represented by a separate pixel value
def load_image( infilename ) :
    img = Image.open( infilename )
    img.load()
    plt.imshow(img)
    plt.show()
    data = np.asarray( img, dtype="int32" )
    list1=[np.array(item).tolist() for item in data]
    return list1
 
 #Define function, count the number of times each pixel appears
def pixel_number_caculate(list2):
    pixel_number={}
    for j in range(len(list2)):
        for e in range(len(list2[0])):
            for i in list2[j][e]:
                if i not in pixel_number. keys():
                    pixel_number[i]=1 #If the pixel is not in the character frequency dictionary, add it directly
                else:
                    pixel_number[i] += 1 #If it exists in the character frequency string dictionary, add one to the corresponding value 
    return pixel_number
 
 #Construct a node, give its value and corresponding weight respectively 
def node_construct(pixel_number): 
    node_list =[]
    for i in range(len(pixel_number)):
        node_list.append(node(weight=pixel_number[i][1],code=str(pixel_number[i][0])))
    return node_list
 

 
 #According to the list of leaf nodes, generate the corresponding Huffman coding tree
def tree_construct(listnode):
    listnode = sorted(listnode,key=lambda node:node.weight) 
    while len(listnode) != 1:
                 # Each time the two pixel points of the weighted value are merged
        low_node0,low_node1 = listnode[0], listnode[1]
        new_change_node = node()
        new_change_node.weight = low_node0.weight + low_node1.weight
        new_change_node.left = low_node0
        new_change_node.right = low_node1
        low_node0.parent = new_change_node
        low_node1.parent = new_change_node
        listnode.remove(low_node0)
        listnode.remove(low_node1)
        listnode.append(new_change_node)
        listnode = sorted(listnode, key=lambda node:node.weight) 
    return listnode
 #The main function of Huffman coding, which completes the coding of pixels by calling other functions
def Huffman_Coding(picture):
    width=len(picture)
    height=len(picture[0])
    depth=len(picture[0][0])
    pixel_number = pixel_number_caculate(picture)
    pixel_number = sorted(pixel_number.items(),key=lambda item:item[1])
           
         #Construct the node list according to the value of the pixel and the number of occurrences 
    node_list = node_construct(pixel_number)
         # Construct a Huffman tree, save the head node
    head = tree_construct(node_list)[0]
           
         #Construction code table
    coding_table = {}
    for e in node_list:
        new_change_node = e
        coding_table.setdefault(e.code,"")
        while new_change_node !=head:
            if new_change_node.parent.left == new_change_node: 
                coding_table[e.code] = "1" + coding_table[e.code] 
            else:
                coding_table[e.code] = "0" + coding_table[e.code] 
            new_change_node = new_change_node.parent
         #Output the gray value and code of each image accumulation point
    for key in coding_table.keys():
        print ("source pixel" + key + "code strength after encoding:" + coding_table[key])
 
 
         #Output encoding table
    #print ("The coding table is:", coding_table)
 
         #Convert the encoding result of the image into a string and save it in txt 
    counter=0
    coding_result = ''
    for i in range(len(picture)):
        for j in range(len(picture[0])):
            for e in picture[i][j]:
                for key,values in coding_table.items(): 
                    counter+=1
                    if str(e) == key:
                        coding_result = coding_result+values 
    
    file = open('coding_result2.txt','w') 
    file.write(coding_result)
    return width,height,depth,coding_table,coding_result


 #Restore the original bmp image, traverse the result of Huffman encoding, for each traversed character is in the codeword list 
 ##Search in #, if not found, add the next character, continue to search, repeat this step until you find it in the code word list 
 #Go to the pixel corresponding to the codeword, and put the pixel value corresponding to the codeword into the pixel list.
def Decoding(width,height,depth,coding_table,coding_result): 
    code_read_now=''#The currently read code 
    new_pixel =np.ones((width,height,depth))
    i = 0
    x=0
    y=0
    z=0
    while i < coding_result.__len__():
        code_read_now = code_read_now + coding_result[i]
        for key in coding_table.keys():
            if code_read_now == coding_table[key]: 
                new_pixel[x][y][z]=int(key)
                code_read_now = ''
                z+=1
                if z==len(new_pixel[0][0]):
                    z=0
                    y+=1
                    if y==len(new_pixel[0]):
                        y=0
                        x+=1
                break
        i+=1
                  
         #Construct a new image
    def save_image( npdata, outfilename ) :
        img1 = Image.fromarray(np.asarray(npdata,dtype="uint8"))
        plt.imshow(img1)
        img1.save( outfilename )
        
    save_image(new_pixel,'decode2.bmp') 
    print("Decoding has been completed: the picture is stored as decode2.bmp")
picture = load_image('sea image.jpg')
a,b,f,c,d=Huffman_Coding(picture)
Decoding(a,b,f,c,d)
# Out:
# source pixel254code strength after encoding:11100110111
# source pixel253code strength after encoding:11100110110
# source pixel255code strength after encoding:01000110111
# source pixel28code strength after encoding:01000110110
# source pixel33code strength after encoding:00111111011
# source pixel27code strength after encoding:00111111010
# source pixel41code strength after encoding:00110010101
# source pixel23code strength after encoding:00110010100
# source pixel31code strength after encoding:00100111111
# source pixel43code strength after encoding:00100111110
# source pixel29code strength after encoding:00100111101
# source pixel19code strength after encoding:00100111100
# source pixel25code strength after encoding:00100111011
# source pixel40code strength after encoding:00100111010
# source pixel32code strength after encoding:00100111001
# source pixel34code strength after encoding:00100111000
# source pixel39code strength after encoding:00011110011
# source pixel35code strength after encoding:00011110010
# source pixel21code strength after encoding:00010111111
# source pixel36code strength after encoding:00010111110
# source pixel20code strength after encoding:00010111101
# source pixel38code strength after encoding:00010111100
# source pixel22code strength after encoding:00010111011
# source pixel24code strength after encoding:00010111010
# source pixel26code strength after encoding:00010111001
# source pixel44code strength after encoding:00010111000
# source pixel42code strength after encoding:00001101011
# source pixel37code strength after encoding:00001101010
# source pixel18code strength after encoding:00000010101
# source pixel30code strength after encoding:00000010100
# source pixel48code strength after encoding:00000010011
# source pixel17code strength after encoding:00000010010
# source pixel45code strength after encoding:1111010101
# source pixel51code strength after encoding:1111010100
# source pixel50code strength after encoding:1110110011
# source pixel49code strength after encoding:1110110010
# source pixel47code strength after encoding:1110110001
# source pixel55code strength after encoding:1110110000
# source pixel58code strength after encoding:1110011010
# source pixel52code strength after encoding:1110011001
# source pixel16code strength after encoding:1110011000
# source pixel57code strength after encoding:1100000111
# source pixel54code strength after encoding:1100000110
# source pixel14code strength after encoding:1011100111
# source pixel62code strength after encoding:1011100110
# source pixel15code strength after encoding:1011100101
# source pixel46code strength after encoding:1011100100
# source pixel53code strength after encoding:1001101011
# source pixel56code strength after encoding:1001101010
# source pixel59code strength after encoding:1001101001
# source pixel12code strength after encoding:1001101000
# source pixel13code strength after encoding:1000101001
# source pixel63code strength after encoding:1000101000
# source pixel61code strength after encoding:1000011101
# source pixel60code strength after encoding:1000011100
# source pixel65code strength after encoding:0111101011
# source pixel10code strength after encoding:0111101010
# source pixel64code strength after encoding:0111010101
# source pixel11code strength after encoding:0111010100
# source pixel68code strength after encoding:0111010011
# source pixel67code strength after encoding:0111010010
# source pixel66code strength after encoding:0110110111
# source pixel9code strength after encoding:0110110110
# source pixel69code strength after encoding:0110010011
# source pixel70code strength after encoding:0110010010
# source pixel71code strength after encoding:0101001111
# source pixel72code strength after encoding:0101001110
# source pixel74code strength after encoding:0100110011
# source pixel252code strength after encoding:0100110010
# source pixel8code strength after encoding:0100110001
# source pixel76code strength after encoding:0100110000
# source pixel7code strength after encoding:0100011010
# source pixel73code strength after encoding:0100011001
# source pixel75code strength after encoding:0100011000
# source pixel77code strength after encoding:0011111100
# source pixel78code strength after encoding:0011001011
# source pixel80code strength after encoding:0011001001
# source pixel79code strength after encoding:0011001000
# source pixel82code strength after encoding:0001111011
# source pixel6code strength after encoding:0001111010
# source pixel81code strength after encoding:0001111000
# source pixel83code strength after encoding:0000110100
# source pixel5code strength after encoding:0000001011
# source pixel85code strength after encoding:0000001000
# source pixel84code strength after encoding:111101011
# source pixel88code strength after encoding:110011111
# source pixel86code strength after encoding:110011110
# source pixel87code strength after encoding:110000010
# source pixel89code strength after encoding:101110001
# source pixel4code strength after encoding:101110000
# source pixel92code strength after encoding:100010101
# source pixel90code strength after encoding:100001111
# source pixel91code strength after encoding:011110100
# source pixel93code strength after encoding:011101011
# source pixel94code strength after encoding:011101000
# source pixel3code strength after encoding:011011010
# source pixel96code strength after encoding:011001000
# source pixel95code strength after encoding:011000011
# source pixel98code strength after encoding:011000010
# source pixel97code strength after encoding:010100110
# source pixel99code strength after encoding:001111111
# source pixel100code strength after encoding:001100001
# source pixel251code strength after encoding:001100000
# source pixel101code strength after encoding:000011011
# source pixel222code strength after encoding:11110100
# source pixel223code strength after encoding:11101101
# source pixel224code strength after encoding:11100111
# source pixel102code strength after encoding:11001110
# source pixel225code strength after encoding:11000000
# source pixel221code strength after encoding:10110101
# source pixel226code strength after encoding:10110100
# source pixel227code strength after encoding:10011011
# source pixel228code strength after encoding:10001011
# source pixel2code strength after encoding:10000110
# source pixel103code strength after encoding:01111111
# source pixel220code strength after encoding:01111110
# source pixel229code strength after encoding:01111011
# source pixel181code strength after encoding:01101111
# source pixel219code strength after encoding:01101110
# source pixel230code strength after encoding:01101100
# source pixel184code strength after encoding:01101011
# source pixel104code strength after encoding:01101010
# source pixel182code strength after encoding:01101001
# source pixel218code strength after encoding:01101000
# source pixel183code strength after encoding:01100111
# source pixel215code strength after encoding:01100110
# source pixel185code strength after encoding:01100101
# source pixel177code strength after encoding:01100011
# source pixel180code strength after encoding:01100010
# source pixel186code strength after encoding:01100000
# source pixel187code strength after encoding:01011111
# source pixel190code strength after encoding:01011110
# source pixel176code strength after encoding:01011101
# source pixel195code strength after encoding:01011100
# source pixel178code strength after encoding:01011011
# source pixel179code strength after encoding:01011010
# source pixel193code strength after encoding:01011001
# source pixel191code strength after encoding:01011000
# source pixel194code strength after encoding:01010111
# source pixel175code strength after encoding:01010110
# source pixel217code strength after encoding:01010101
# source pixel189code strength after encoding:01010100
# source pixel188code strength after encoding:01010010
# source pixel192code strength after encoding:01010001
# source pixel214code strength after encoding:01010000
# source pixel216code strength after encoding:01001111
# source pixel196code strength after encoding:01001110
# source pixel197code strength after encoding:01001101
# source pixel198code strength after encoding:01001001
# source pixel174code strength after encoding:01001000
# source pixel173code strength after encoding:01000111
# source pixel231code strength after encoding:01000101
# source pixel105code strength after encoding:01000100
# source pixel119code strength after encoding:01000001
# source pixel213code strength after encoding:01000000
# source pixel118code strength after encoding:00111110
# source pixel199code strength after encoding:00111101
# source pixel232code strength after encoding:00111100
# source pixel120code strength after encoding:00111011
# source pixel117code strength after encoding:00111010
# source pixel121code strength after encoding:00110111
# source pixel136code strength after encoding:00110110
# source pixel137code strength after encoding:00110101
# source pixel172code strength after encoding:00110100
# source pixel200code strength after encoding:00110011
# source pixel139code strength after encoding:00110001
# source pixel106code strength after encoding:00101111
# source pixel212code strength after encoding:00101110
# source pixel138code strength after encoding:00101101
# source pixel122code strength after encoding:00101100
# source pixel142code strength after encoding:00101011
# source pixel116code strength after encoding:00101010
# source pixel168code strength after encoding:00101001
# source pixel135code strength after encoding:00101000
# source pixel210code strength after encoding:00100110
# source pixel211code strength after encoding:00100101
# source pixel141code strength after encoding:00100100
# source pixel201code strength after encoding:00100011
# source pixel123code strength after encoding:00100010
# source pixel171code strength after encoding:00100001
# source pixel126code strength after encoding:00100000
# source pixel134code strength after encoding:00011111
# source pixel140code strength after encoding:00011101
# source pixel127code strength after encoding:00011100
# source pixel170code strength after encoding:00011011
# source pixel169code strength after encoding:00011010
# source pixel125code strength after encoding:00011001
# source pixel202code strength after encoding:00011000
# source pixel128code strength after encoding:00010110
# source pixel165code strength after encoding:00010101
# source pixel209code strength after encoding:00010100
# source pixel145code strength after encoding:00010011
# source pixel250code strength after encoding:00010010
# source pixel124code strength after encoding:00010001
# source pixel107code strength after encoding:00010000
# source pixel167code strength after encoding:00001111
# source pixel143code strength after encoding:00001110
# source pixel205code strength after encoding:00001100
# source pixel115code strength after encoding:00000111
# source pixel208code strength after encoding:00000110
# source pixel164code strength after encoding:00000011
# source pixel148code strength after encoding:00000001
# source pixel166code strength after encoding:00000000
# source pixel144code strength after encoding:1111111
# source pixel207code strength after encoding:1111110
# source pixel155code strength after encoding:1111011
# source pixel132code strength after encoding:1111001
# source pixel206code strength after encoding:1111000
# source pixel203code strength after encoding:1110111
# source pixel204code strength after encoding:1110101
# source pixel133code strength after encoding:1110100
# source pixel163code strength after encoding:1110010
# source pixel131code strength after encoding:1110001
# source pixel108code strength after encoding:1110000
# source pixel152code strength after encoding:1101111
# source pixel157code strength after encoding:1101110
# source pixel154code strength after encoding:1101011
# source pixel235code strength after encoding:1101010
# source pixel147code strength after encoding:1101001
# source pixel114code strength after encoding:1101000
# source pixel130code strength after encoding:1100110
# source pixel146code strength after encoding:1100101
# source pixel237code strength after encoding:1100100
# source pixel153code strength after encoding:1100001
# source pixel150code strength after encoding:1011101
# source pixel158code strength after encoding:1011011
# source pixel160code strength after encoding:1011001
# source pixel233code strength after encoding:1011000
# source pixel129code strength after encoding:1001111
# source pixel151code strength after encoding:1001110
# source pixel234code strength after encoding:1001100
# source pixel113code strength after encoding:1001001
# source pixel149code strength after encoding:1001000
# source pixel109code strength after encoding:1000111
# source pixel236code strength after encoding:1000110
# source pixel159code strength after encoding:1000100
# source pixel112code strength after encoding:1000010
# source pixel238code strength after encoding:1000001
# source pixel110code strength after encoding:1000000
# source pixel161code strength after encoding:0111110
# source pixel156code strength after encoding:0111100
# source pixel111code strength after encoding:0111011
# source pixel162code strength after encoding:0111001
# source pixel239code strength after encoding:0111000
# source pixel240code strength after encoding:0100101
# source pixel241code strength after encoding:0100001
# source pixel249code strength after encoding:0011100
# source pixel244code strength after encoding:0000101
# source pixel245code strength after encoding:0000100
# source pixel242code strength after encoding:0000010
# source pixel246code strength after encoding:111110
# source pixel248code strength after encoding:110110
# source pixel243code strength after encoding:110001
# source pixel247code strength after encoding:101111
# source pixel1code strength after encoding:100101
# source pixel0code strength after encoding:1010
# Decoding has been completed: the picture is stored as decode2.bmp
